# %%
import pandas as pd
import yfinance as yf

# %%
start = "2021-01-04"
end = "2024-06-01"

# %%
symbol = [ "^GSPC", "GC=F", "BTC-USD", "ADA-USD"]

# %%
df = yf.download(symbol, start ,end)
df
# Out:
# [*********************100%%**********************]  4 of 4 completed
#            Adj Close                                  Close             \
#              ADA-USD    BTC-USD      GC=F     ^GSPC ADA-USD    BTC-USD
# Date
# 2021-01-04    0.2248 31971.9141 1944.7000 3700.6499  0.2248 31971.9141
# 2021-01-05    0.2583 33992.4297 1952.7000 3726.8601  0.2583 33992.4297
# 2021-01-06    0.3319 36824.3633 1906.9000 3748.1399  0.3319 36824.3633
# 2021-01-07    0.3000 39371.0430 1912.3000 3803.7900  0.3000 39371.0430
# 2021-01-08    0.3056 40797.6094 1834.1000 3824.6799  0.3056 40797.6094
# ...              ...        ...       ...       ...     ...        ...
# 2024-05-27    0.4680 69394.5547       NaN       NaN  0.4680 69394.5547
# 2024-05-28    0.4570 68296.2188 2355.2000 5306.0400  0.4570 68296.2188
# 2024-05-29    0.4510 67578.0938 2340.3000 5266.9502  0.4510 67578.0938
# 2024-05-30    0.4466 68364.9922 2342.8999 5235.4800  0.4466 68364.9922
# 2024-05-31    0.4475 67491.4141 2322.8999 5277.5098  0.4475 67491.4141
#
#                                   High             ...       Low            \
#                 GC=F     ^GSPC ADA-USD    BTC-USD  ...      GC=F     ^GSPC
# Date                                               ...
# 2021-01-04 1944.7000 3700.6499  0.2397 33440.2188  ... 1912.2000 3662.7100
# 2021-01-05 1952.7000 3726.8601  0.2649 34437.5898  ... 1941.3000 3695.0701
# 2021-01-06 1906.9000 3748.1399  0.3463 36879.6992  ... 1901.5000 3705.3401
# 2021-01-07 1912.3000 3803.7900  0.3533 40180.3672  ... 1912.0000 3764.7100
# 2021-01-08 1834.1000 3824.6799  0.3202 41946.7383  ... 1834.1000 3783.6001
# ...              ...       ...     ...        ...  ...       ...       ...
# 2024-05-27       NaN       NaN  0.4740 70597.8828  ...       NaN       NaN
# 2024-05-28 2355.2000 5306.0400  0.4684 69514.6406  ... 2336.8999 5280.8901
# 2024-05-29 2340.3000 5266.9502  0.4631 68852.4609  ... 2340.3000 5262.7002
# 2024-05-30 2342.8999 5235.4800  0.4545 69500.5391  ... 2320.8000 5222.1001
# 2024-05-31 2322.8999 5277.5098  0.4550 68999.5625  ... 2319.0000 5191.6802
#
#               Open                                     Volume               \
#            ADA-USD    BTC-USD      GC=F     ^GSPC     ADA-USD      BTC-USD
# Date
# 2021-01-04  0.2052 32810.9492 1912.2000 3764.6101  3260699086  81163475344
# 2021-01-05  0.2248 31977.0410 1941.7000 3698.0200  4097207384  67547324782
# 2021-01-06  0.2585 34013.6133 1952.0000 3712.2000  6170988900  75289433811
# 2021-01-07  0.3323 36833.8750 1922.6000 3764.7100  5149188552  84762141031
# 2021-01-08  0.3004 39381.7656 1908.0000 3815.0500  4560690774  88107519480
# ...            ...        ...       ...       ...         ...          ...
# 2024-05-27  0.4584 68512.1797       NaN       NaN   323304261  25870990717
# 2024-05-28  0.4680 69392.1953 2336.8999 5315.9102   418594476  32722265965
# 2024-05-29  0.4570 68296.3516 2340.3000 5278.7300   350482630  26707072906
# 2024-05-30  0.4510 67576.0859 2336.8999 5259.7700   356151973  29509712534
# 2024-05-31  0.4466 68362.5156 2344.1001 5243.2100   290913148  27387283769
#
#
#                   GC=F           ^GSPC
# Date
# 2021-01-04    154.0000 5015000000.0000
# 2021-01-05    113.0000 4591020000.0000
# 2021-01-06    331.0000 6064110000.0000
# 2021-01-07    122.0000 5099160000.0000
# 2021-01-08     60.0000 4773040000.0000
# ...                ...             ...
# 2024-05-27         NaN             NaN
# 2024-05-28     26.0000 3751540000.0000
# 2024-05-29 119317.0000 3552750000.0000
# 2024-05-30  32587.0000 3818750000.0000
# 2024-05-31    941.0000 5437160000.0000
#
# [1244 rows x 24 columns]

# %%
df.to_csv("multi_assets.csv")

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")
# Out:
# C:\Users\marke\AppData\Local\Temp\ipykernel_28016\3115518178.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
pd.read_csv ("multi_assets.csv", header = [0,1], index_col = 0, parse_dates =[0])
# Out:
#            Adj Close                                  Close             \
#              ADA-USD    BTC-USD      GC=F     ^GSPC ADA-USD    BTC-USD
# Date
# 2021-01-04    0.2248 31971.9141 1944.7000 3700.6499  0.2248 31971.9141
# 2021-01-05    0.2583 33992.4297 1952.7000 3726.8601  0.2583 33992.4297
# 2021-01-06    0.3319 36824.3633 1906.9000 3748.1399  0.3319 36824.3633
# 2021-01-07    0.3000 39371.0430 1912.3000 3803.7900  0.3000 39371.0430
# 2021-01-08    0.3056 40797.6094 1834.1000 3824.6799  0.3056 40797.6094
# ...              ...        ...       ...       ...     ...        ...
# 2024-05-27    0.4680 69394.5547       NaN       NaN  0.4680 69394.5547
# 2024-05-28    0.4570 68296.2188 2355.2000 5306.0400  0.4570 68296.2188
# 2024-05-29    0.4510 67578.0938 2340.3000 5266.9502  0.4510 67578.0938
# 2024-05-30    0.4466 68364.9922 2342.8999 5235.4800  0.4466 68364.9922
# 2024-05-31    0.4475 67491.4141 2322.8999 5277.5098  0.4475 67491.4141
#
#                                   High             ...       Low            \
#                 GC=F     ^GSPC ADA-USD    BTC-USD  ...      GC=F     ^GSPC
# Date                                               ...
# 2021-01-04 1944.7000 3700.6499  0.2397 33440.2188  ... 1912.2000 3662.7100
# 2021-01-05 1952.7000 3726.8601  0.2649 34437.5898  ... 1941.3000 3695.0701
# 2021-01-06 1906.9000 3748.1399  0.3463 36879.6992  ... 1901.5000 3705.3401
# 2021-01-07 1912.3000 3803.7900  0.3533 40180.3672  ... 1912.0000 3764.7100
# 2021-01-08 1834.1000 3824.6799  0.3202 41946.7383  ... 1834.1000 3783.6001
# ...              ...       ...     ...        ...  ...       ...       ...
# 2024-05-27       NaN       NaN  0.4740 70597.8828  ...       NaN       NaN
# 2024-05-28 2355.2000 5306.0400  0.4684 69514.6406  ... 2336.8999 5280.8901
# 2024-05-29 2340.3000 5266.9502  0.4631 68852.4609  ... 2340.3000 5262.7002
# 2024-05-30 2342.8999 5235.4800  0.4545 69500.5391  ... 2320.8000 5222.1001
# 2024-05-31 2322.8999 5277.5098  0.4550 68999.5625  ... 2319.0000 5191.6802
#
#               Open                                     Volume               \
#            ADA-USD    BTC-USD      GC=F     ^GSPC     ADA-USD      BTC-USD
# Date
# 2021-01-04  0.2052 32810.9492 1912.2000 3764.6101  3260699086  81163475344
# 2021-01-05  0.2248 31977.0410 1941.7000 3698.0200  4097207384  67547324782
# 2021-01-06  0.2585 34013.6133 1952.0000 3712.2000  6170988900  75289433811
# 2021-01-07  0.3323 36833.8750 1922.6000 3764.7100  5149188552  84762141031
# 2021-01-08  0.3004 39381.7656 1908.0000 3815.0500  4560690774  88107519480
# ...            ...        ...       ...       ...         ...          ...
# 2024-05-27  0.4584 68512.1797       NaN       NaN   323304261  25870990717
# 2024-05-28  0.4680 69392.1953 2336.8999 5315.9102   418594476  32722265965
# 2024-05-29  0.4570 68296.3516 2340.3000 5278.7300   350482630  26707072906
# 2024-05-30  0.4510 67576.0859 2336.8999 5259.7700   356151973  29509712534
# 2024-05-31  0.4466 68362.5156 2344.1001 5243.2100   290913148  27387283769
#
#
#                   GC=F           ^GSPC
# Date
# 2021-01-04    154.0000 5015000000.0000
# 2021-01-05    113.0000 4591020000.0000
# 2021-01-06    331.0000 6064110000.0000
# 2021-01-07    122.0000 5099160000.0000
# 2021-01-08     60.0000 4773040000.0000
# ...                ...             ...
# 2024-05-27         NaN             NaN
# 2024-05-28     26.0000 3751540000.0000
# 2024-05-29 119317.0000 3552750000.0000
# 2024-05-30  32587.0000 3818750000.0000
# 2024-05-31    941.0000 5437160000.0000
#
# [1244 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1244 entries, 2021-01-04 to 2024-05-31
# Freq: D
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, ADA-USD)  1244 non-null   float64
#  1   (Adj Close, BTC-USD)  1244 non-null   float64
#  2   (Adj Close, GC=F)     859 non-null    float64
#  3   (Adj Close, ^GSPC)    858 non-null    float64
#  4   (Close, ADA-USD)      1244 non-null   float64
#  5   (Close, BTC-USD)      1244 non-null   float64
#  6   (Close, GC=F)         859 non-null    float64
#  7   (Close, ^GSPC)        858 non-null    float64
#  8   (High, ADA-USD)       1244 non-null   float64
#  9   (High, BTC-USD)       1244 non-null   float64
#  10  (High, GC=F)          859 non-null    float64
#  11  (High, ^GSPC)         858 non-null    float64
#  12  (Low, ADA-USD)        1244 non-null   float64
#  13  (Low, BTC-USD)        1244 non-null   float64
#  14  (Low, GC=F)           859 non-null    float64
#  15  (Low, ^GSPC)          858 non-null    float64
#  16  (Open, ADA-USD)       1244 non-null   float64
#  17  (Open, BTC-USD)       1244 non-null   float64
#  18  (Open, GC=F)          859 non-null    float64
#  19  (Open, ^GSPC)         858 non-null    float64
#  20  (Volume, ADA-USD)     1244 non-null   int64
#  21  (Volume, BTC-USD)     1244 non-null   int64
#  22  (Volume, GC=F)        859 non-null    float64
#  23  (Volume, ^GSPC)       858 non-null    float64
# dtypes: float64(22), int64(2)
# memory usage: 243.0 KB

# %%
df.Close
# Out:
#             ADA-USD    BTC-USD      GC=F     ^GSPC
# Date
# 2021-01-04   0.2248 31971.9141 1944.7000 3700.6499
# 2021-01-05   0.2583 33992.4297 1952.7000 3726.8601
# 2021-01-06   0.3319 36824.3633 1906.9000 3748.1399
# 2021-01-07   0.3000 39371.0430 1912.3000 3803.7900
# 2021-01-08   0.3056 40797.6094 1834.1000 3824.6799
# ...             ...        ...       ...       ...
# 2024-05-27   0.4680 69394.5547       NaN       NaN
# 2024-05-28   0.4570 68296.2188 2355.2000 5306.0400
# 2024-05-29   0.4510 67578.0938 2340.3000 5266.9502
# 2024-05-30   0.4466 68364.9922 2342.8999 5235.4800
# 2024-05-31   0.4475 67491.4141 2322.8999 5277.5098
#
# [1244 rows x 4 columns]

# %%
df.loc[:, ("Close", "ADA-USD")]
# Out:
# Date
# 2021-01-04   0.2248
# 2021-01-05   0.2583
# 2021-01-06   0.3319
# 2021-01-07   0.3000
# 2021-01-08   0.3056
#               ...
# 2024-05-27   0.4680
# 2024-05-28   0.4570
# 2024-05-29   0.4510
# 2024-05-30   0.4466
# 2024-05-31   0.4475
# Freq: D, Name: (Close, ADA-USD), Length: 1244, dtype: float64

# %%
close = df.Close.copy()
close
# Out:
#             ADA-USD    BTC-USD      GC=F     ^GSPC
# Date
# 2021-01-04   0.2248 31971.9141 1944.7000 3700.6499
# 2021-01-05   0.2583 33992.4297 1952.7000 3726.8601
# 2021-01-06   0.3319 36824.3633 1906.9000 3748.1399
# 2021-01-07   0.3000 39371.0430 1912.3000 3803.7900
# 2021-01-08   0.3056 40797.6094 1834.1000 3824.6799
# ...             ...        ...       ...       ...
# 2024-05-27   0.4680 69394.5547       NaN       NaN
# 2024-05-28   0.4570 68296.2188 2355.2000 5306.0400
# 2024-05-29   0.4510 67578.0938 2340.3000 5266.9502
# 2024-05-30   0.4466 68364.9922 2342.8999 5235.4800
# 2024-05-31   0.4475 67491.4141 2322.8999 5277.5098
#
# [1244 rows x 4 columns]

# %%
close.describe()
# Out:
#         ADA-USD    BTC-USD      GC=F     ^GSPC
# count 1244.0000  1244.0000  859.0000  858.0000
# mean     0.7973 37718.2207 1888.0710 4322.5496
# std      0.6002 14562.0259  152.0354  389.6860
# min      0.2248 15787.2842 1623.3000 3577.0300
# 25%      0.3673 26320.2173 1784.9500 4004.2300
# 50%      0.5084 36112.2871 1852.8000 4292.8650
# 75%      1.1734 47111.1377 1962.5000 4535.2902
# max      2.9682 73083.5000 2433.8999 5321.4102

# %%
#close.dropna().plot(figsize = (15,8), fontsize = 13)
#plt.legend(fontsize = 13)
#plt.show()

# %% [markdown]
# ## Normalizing Financial Time Series to a Base Value (100)

# %%
# First Price 
close.iloc[0,0]
# Out:
# 0.2247619926929474

# %%
close.div(close.iloc[0,0])
# Out:
#             ADA-USD     BTC-USD       GC=F      ^GSPC
# Date
# 2021-01-04   1.0000 142247.8671  8652.2633 16464.7495
# 2021-01-05   1.1493 151237.4458  8687.8566 16581.3626
# 2021-01-06   1.4767 163837.1454  8484.0858 16676.0396
# 2021-01-07   1.3347 175167.7074  8508.1113 16923.6355
# 2021-01-08   1.3596 181514.7165  8160.1874 17016.5778
# ...             ...         ...        ...        ...
# 2024-05-27   2.0820 308746.8386        NaN        NaN
# 2024-05-28   2.0332 303860.1764 10478.6398 23607.3723
# 2024-05-29   2.0065 300665.1300 10412.3478 23433.4557
# 2024-05-30   1.9869 304166.1598 10423.9150 23293.4400
# 2024-05-31   1.9908 300279.4790 10334.9320 23480.4368
#
# [1244 rows x 4 columns]

# %%
# First Prices all tickers
close.iloc[0]
# Out:
# ADA-USD       0.2248
# BTC-USD   31971.9141
# GC=F       1944.7000
# ^GSPC      3700.6499
# Name: 2021-01-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#             ADA-USD  BTC-USD     GC=F    ^GSPC
# Date
# 2021-01-04 100.0000 100.0000 100.0000 100.0000
# 2021-01-05 114.9278 106.3197 100.4114 100.7083
# 2021-01-06 147.6664 115.1772  98.0563 101.2833
# 2021-01-07 133.4656 123.1426  98.3339 102.7871
# 2021-01-08 135.9647 127.6045  94.3127 103.3516
# ...             ...      ...      ...      ...
# 2024-05-27 208.2038 217.0485      NaN      NaN
# 2024-05-28 203.3217 213.6132 121.1087 143.3813
# 2024-05-29 200.6545 211.3671 120.3425 142.3250
# 2024-05-30 198.6906 213.8283 120.4762 141.4746
# 2024-05-31 199.0822 211.0959 119.4477 142.6103
#
# [1244 rows x 4 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close.to_csv("close.csv")
